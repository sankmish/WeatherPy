# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + api_key + "&q="
cityNames = []
date = []
lat = []
lng = []
cloudiness = []
maxTemp = []
windSpeed = []
country = []
humidity = []


print("Beginning Data Retrieval")
print("-------------------------------------")
for city in cities:
    print("Processing Record of | " + city)
    response = requests.get(query_url + city).json()
    if response['cod'] == '404':
        print("City not found.  Skipping...")
    else:
        cityNames.append(response['name'])
        date.append(response['dt'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        cloudiness.append(response['clouds']['all'])
        maxTemp.append(response['main']['temp_max'])
        windSpeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        humidity.append(response['main']['humidity'])
print("-------------------------------------")
print("Data Retrieval Complete")
print("-------------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record of | hermanus
# Processing Record of | lorengau
# Processing Record of | norman wells
# Processing Record of | lompoc
# Processing Record of | atuona
# Processing Record of | hami
# Processing Record of | sinjai
# Processing Record of | geraldton
# Processing Record of | rikitea
# Processing Record of | jamestown
# Processing Record of | taolanaro
# City not found.  Skipping...
# Processing Record of | agirish
# Processing Record of | amderma
# City not found.  Skipping...
# Processing Record of | cidreira
# Processing Record of | nikolskoye
# Processing Record of | shimoda
# Processing Record of | port elizabeth
# Processing Record of | schermbeck
# Processing Record of | ushuaia
# Processing Record of | strezhevoy
# Processing Record of | dipkarpaz
# City not found.  Skipping...
# Processing Record of | ayan
# Processing Record of | cape town
# Processing Record of | kruisfontein
# Processing Record of | bambous virieux
# Processing Record of | busselton
# Processing Record of | ribeira grande
# Processing Record of | saint pete beach
# Processing Record of | leningradskiy
# Processing Record of | bur gabo
# City not found.  Skipping...
# Processing Record of | tuatapere
# Processing Record of | east london
# Processing Record of | grand gaube
# Processing Record of | victoria
# Processing Record of | butaritari
# Processing Record of | saint george
# Processing Record of | alice springs
# Processing Record of | vaitupu
# City not found.  Skipping...
# Processing Record of | guerrero negro
# Processing Record of | sentyabrskiy
# City not found.  Skipping...
# Processing Record of | hithadhoo
# Processing Record of | abhar
# Processing Record of | erie
# Processing Record of | albany
# Processing Record of | karratha
# Processing Record of | high level
# Processing Record of | acarau
# City not found.  Skipping...
# Processing Record of | rio gallegos
# Processing Record of | hobart
# Processing Record of | sisimiut
# Processing Record of | mataura
# Processing Record of | general roca
# Processing Record of | acapulco
# Processing Record of | hilo
# Processing Record of | punta arenas
# Processing Record of | mount gambier
# Processing Record of | georgetown
# Processing Record of | kamenskoye
# City not found.  Skipping...
# Processing Record of | beringovskiy
# Processing Record of | samusu
# City not found.  Skipping...
# Processing Record of | kapaa
# Processing Record of | verkhoyansk
# Processing Record of | adrar
# Processing Record of | avarua
# Processing Record of | los llanos de aridane
# Processing Record of | morant bay
# Processing Record of | sailana
# Processing Record of | banjar
# Processing Record of | rundu
# Processing Record of | new norfolk
# Processing Record of | oda
# Processing Record of | bilibino
# Processing Record of | esperance
# Processing Record of | zaysan
# Processing Record of | mineiros
# Processing Record of | mahebourg
# Processing Record of | umzimvubu
# City not found.  Skipping...
# Processing Record of | faanui
# Processing Record of | padang
# Processing Record of | high rock
# Processing Record of | menzelinsk
# Processing Record of | puerto ayora
# Processing Record of | ancud
# Processing Record of | salalah
# Processing Record of | chagda
# City not found.  Skipping...
# Processing Record of | hobyo
# Processing Record of | tsihombe
# City not found.  Skipping...
# Processing Record of | praya
# Processing Record of | yabelo
# Processing Record of | yellowknife
# Processing Record of | ziarat
# Processing Record of | olafsvik
# City not found.  Skipping...
# Processing Record of | kavieng
# Processing Record of | rungata
# City not found.  Skipping...
# Processing Record of | ossora
# Processing Record of | tuktoyaktuk
# Processing Record of | mys shmidta
# City not found.  Skipping...
# Processing Record of | hereford
# Processing Record of | jovellar
# Processing Record of | kodiak
# Processing Record of | tidore
# City not found.  Skipping...
# Processing Record of | port alfred
# Processing Record of | praia da vitoria
# Processing Record of | ilulissat
# Processing Record of | dashitou
# Processing Record of | mwene-ditu
# Processing Record of | arman
# Processing Record of | port-gentil
# Processing Record of | lagoa
# Processing Record of | tiksi
# Processing Record of | moiyabana
# City not found.  Skipping...
# Processing Record of | nola
# Processing Record of | avera
# Processing Record of | byron bay
# Processing Record of | coquimbo
# Processing Record of | klaeng
# Processing Record of | aksarka
# Processing Record of | elat
# Processing Record of | pevek
# Processing Record of | svetlyy
# City not found.  Skipping...
# Processing Record of | barentsburg
# City not found.  Skipping...
# Processing Record of | bredasdorp
# Processing Record of | talnakh
# Processing Record of | mahajanga
# Processing Record of | male
# Processing Record of | aklavik
# Processing Record of | vallenar
# Processing Record of | talcahuano
# Processing Record of | baykit
# Processing Record of | kachiry
# Processing Record of | inirida
# Processing Record of | barsovo
# Processing Record of | ahipara
# Processing Record of | vaini
# Processing Record of | bonthe
# Processing Record of | itoman
# Processing Record of | attawapiskat
# City not found.  Skipping...
# Processing Record of | narsaq
# Processing Record of | uglegorsk
# Processing Record of | honiara
# Processing Record of | cherskiy
# Processing Record of | provideniya
# Processing Record of | gap
# Processing Record of | freeport
# Processing Record of | talas
# Processing Record of | camopi
# Processing Record of | bluff
# Processing Record of | north bend
# Processing Record of | iraray
# Processing Record of | chokurdakh
# Processing Record of | tual
# Processing Record of | broome
# Processing Record of | kayseri
# Processing Record of | bom jesus
# Processing Record of | booue
# Processing Record of | barrow
# Processing Record of | corralillo
# Processing Record of | omboue
# Processing Record of | mendahara
# City not found.  Skipping...
# Processing Record of | puerto del rosario
# Processing Record of | meulaboh
# Processing Record of | cabedelo
# Processing Record of | fomboni
# Processing Record of | aktau
# Processing Record of | tasiilaq
# Processing Record of | muravlenko
# Processing Record of | qaanaaq
# Processing Record of | mitsamiouli
# Processing Record of | gao
# Processing Record of | hamilton
# Processing Record of | gazojak
# Processing Record of | poum
# Processing Record of | hinton
# Processing Record of | srednekolymsk
# Processing Record of | severo-kurilsk
# Processing Record of | umm kaddadah
# Processing Record of | vestmannaeyjar
# Processing Record of | zhigansk
# Processing Record of | khorramshahr
# Processing Record of | ixtlahuacan del rio
# Processing Record of | kitimat
# Processing Record of | mizan teferi
# Processing Record of | kaitangata
# Processing Record of | chalmette
# Processing Record of | bengkulu
# City not found.  Skipping...
# Processing Record of | rincon
# Processing Record of | khudumelapye
# Processing Record of | lasa
# Processing Record of | thompson
# Processing Record of | longyearbyen
# Processing Record of | cocobeach
# Processing Record of | taltal
# Processing Record of | vyazma
# Processing Record of | goksun
# Processing Record of | plock
# Processing Record of | montepuez
# Processing Record of | barcarena
# Processing Record of | alofi
# Processing Record of | isangel
# Processing Record of | taoudenni
# Processing Record of | carnarvon
# Processing Record of | katsuura
# Processing Record of | ewa beach
# Processing Record of | saskylakh
# Processing Record of | ambilobe
# Processing Record of | atar
# Processing Record of | yulara
# Processing Record of | namatanai
# Processing Record of | zambezi
# Processing Record of | klaksvik
# Processing Record of | kyabram
# Processing Record of | sao filipe
# Processing Record of | cayenne
# Processing Record of | bethel
# Processing Record of | takoradi
# Processing Record of | luwuk
# Processing Record of | riyadh
# Processing Record of | quelimane
# Processing Record of | mareeba
# Processing Record of | caravelas
# Processing Record of | cam pha
# City not found.  Skipping...
# Processing Record of | khatanga
# Processing Record of | san carlos de bariloche
# Processing Record of | road town
# Processing Record of | college
# Processing Record of | dikson
# Processing Record of | quatre cocos
# Processing Record of | sur
# Processing Record of | shitanjing
# Processing Record of | ouallam
# Processing Record of | cabo san lucas
# Processing Record of | monrovia
# Processing Record of | bilma
# Processing Record of | kamaishi
# Processing Record of | nanortalik
# Processing Record of | comodoro rivadavia
# Processing Record of | cape canaveral
# Processing Record of | bud
# Processing Record of | hasaki
# Processing Record of | yoichi
# Processing Record of | santa cruz de tenerife
# Processing Record of | broken hill
# Processing Record of | kushima
# Processing Record of | bartica
# Processing Record of | aguada de pasajeros
# Processing Record of | boca do acre
# Processing Record of | illoqqortoormiut
# City not found.  Skipping...
# Processing Record of | lady frere
# Processing Record of | hvide sande
# Processing Record of | sao felix do xingu
# Processing Record of | tanabe
# Processing Record of | sitka
# Processing Record of | saint-philippe
# Processing Record of | pisco
# Processing Record of | fare
# Processing Record of | eureka
# Processing Record of | torbay
# Processing Record of | alindao
# Processing Record of | ciudad bolivar
# Processing Record of | mar del plata
# Processing Record of | sistranda
# Processing Record of | upernavik
# Processing Record of | kushmurun
# City not found.  Skipping...
# Processing Record of | pyapon
# Processing Record of | san remigio
# Processing Record of | solnechnyy
# Processing Record of | waimana
# Processing Record of | deer lake
# Processing Record of | sovetskoye
# Processing Record of | belushya guba
# City not found.  Skipping...
# Processing Record of | shenkursk
# Processing Record of | marcona
# City not found.  Skipping...
# Processing Record of | linares
# Processing Record of | smithers
# Processing Record of | oranjemund
# Processing Record of | olyka
# Processing Record of | san andres
# Processing Record of | hualmay
# Processing Record of | komsomolskiy
# Processing Record of | margate
# Processing Record of | tucurui
# Processing Record of | aliwal north
# Processing Record of | arraial do cabo
# Processing Record of | piacabucu
# Processing Record of | ust-koksa
# Processing Record of | kununurra
# Processing Record of | kuche
# City not found.  Skipping...
# Processing Record of | erzin
# Processing Record of | nouakchott
# Processing Record of | dolores
# Processing Record of | altay
# Processing Record of | rocha
# Processing Record of | doba
# Processing Record of | duluth
# Processing Record of | hailey
# Processing Record of | iralaya
# Processing Record of | gorontalo
# Processing Record of | buluang
# Processing Record of | port lincoln
# Processing Record of | kameshkovo
# Processing Record of | serta
# Processing Record of | balabac
# Processing Record of | gibsons
# Processing Record of | antofagasta
# Processing Record of | okhotsk
# Processing Record of | port said
# Processing Record of | ola
# Processing Record of | salihli
# Processing Record of | adilabad
# Processing Record of | burnie
# Processing Record of | boa vista
# Processing Record of | pahrump
# Processing Record of | rota
# Processing Record of | kiama
# Processing Record of | gornopravdinsk
# Processing Record of | vao
# Processing Record of | xichang
# Processing Record of | port moresby
# Processing Record of | kholodnyy
# Processing Record of | buchanan
# Processing Record of | grand centre
# City not found.  Skipping...
# Processing Record of | lowestoft
# Processing Record of | san patricio
# Processing Record of | sola
# Processing Record of | lincoln
# Processing Record of | mullaitivu
# City not found.  Skipping...
# Processing Record of | puksoozero
# Processing Record of | grand-lahou
# Processing Record of | ponta do sol
# Processing Record of | odienne
# Processing Record of | ust-nera
# Processing Record of | pacific grove
# Processing Record of | evensk
# Processing Record of | chapais
# Processing Record of | grand river south east
# City not found.  Skipping...
# Processing Record of | sao joao da barra
# Processing Record of | xining
# Processing Record of | airai
# Processing Record of | corinto
# Processing Record of | morondava
# Processing Record of | manutuke
# Processing Record of | pascagoula
# Processing Record of | wakkanai
# Processing Record of | tautira
# Processing Record of | chuy
# Processing Record of | cabra
# Processing Record of | vrangel
# Processing Record of | luderitz
# Processing Record of | castro
# Processing Record of | laguna
# Processing Record of | fairbanks
# Processing Record of | belyye berega
# Processing Record of | atherton
# Processing Record of | haines junction
# Processing Record of | ljungby
# Processing Record of | kurilsk
# Processing Record of | pringsewu
# Processing Record of | qandala
# Processing Record of | baracoa
# Processing Record of | ust-ishim
# Processing Record of | saleaula
# City not found.  Skipping...
# Processing Record of | mukhen
# Processing Record of | stipsi
# City not found.  Skipping...
# Processing Record of | afgoye
# City not found.  Skipping...
# Processing Record of | dali
# Processing Record of | anloga
# Processing Record of | presidencia roque saenz pena
# Processing Record of | serafimovich
# Processing Record of | matara
# Processing Record of | jasper
# Processing Record of | bargal
# City not found.  Skipping...
# Processing Record of | nicoya
# Processing Record of | sassandra
# Processing Record of | hambantota
# Processing Record of | bollnas
# Processing Record of | atbasar
# Processing Record of | ondjiva
# Processing Record of | balimo
# City not found.  Skipping...
# Processing Record of | nishihara
# Processing Record of | nome
# Processing Record of | abu samrah
# Processing Record of | provost
# Processing Record of | sabang
# Processing Record of | balikpapan
# Processing Record of | faya
# Processing Record of | clyde river
# Processing Record of | eyl
# Processing Record of | half moon bay
# Processing Record of | lavrentiya
# Processing Record of | abha
# Processing Record of | yirol
# City not found.  Skipping...
# Processing Record of | biak
# Processing Record of | coihaique
# Processing Record of | vanino
# Processing Record of | hay river
# Processing Record of | lebu
# Processing Record of | ust-kuyga
# Processing Record of | yerbogachen
# Processing Record of | palabuhanratu
# City not found.  Skipping...
# Processing Record of | los angeles
# Processing Record of | wyndham
# Processing Record of | jumla
# Processing Record of | vanimo
# Processing Record of | coromandel
# Processing Record of | aripuana
# Processing Record of | saldanha
# Processing Record of | havre-saint-pierre
# Processing Record of | saint-augustin
# Processing Record of | ghanzi
# Processing Record of | trapani
# Processing Record of | hovd
# Processing Record of | punta alta
# Processing Record of | romans-sur-isere
# Processing Record of | bani
# Processing Record of | divnogorsk
# Processing Record of | caruray
# Processing Record of | twin falls
# Processing Record of | inhambane
# Processing Record of | la asuncion
# Processing Record of | waipawa
# Processing Record of | meiganga
# Processing Record of | kulu
# Processing Record of | naze
# Processing Record of | kropotkin
# Processing Record of | luocheng
# Processing Record of | collie
# Processing Record of | svencionys
# Processing Record of | cody
# Processing Record of | tatarsk
# Processing Record of | saquena
# Processing Record of | tiznit
# Processing Record of | formosa
# Processing Record of | hakvik
# City not found.  Skipping...
# Processing Record of | mount darwin
# Processing Record of | nemuro
# Processing Record of | souillac
# Processing Record of | lydenburg
# Processing Record of | verkhnechusovskiye gorodki
# Processing Record of | erenhot
# Processing Record of | santa isabel do rio negro
# Processing Record of | tari
# Processing Record of | muzquiz
# City not found.  Skipping...
# Processing Record of | necochea
# Processing Record of | salaverry
# Processing Record of | ishinomaki
# Processing Record of | lichinga
# Processing Record of | plastun
# Processing Record of | san lorenzo
# Processing Record of | saint-pascal
# City not found.  Skipping...
# Processing Record of | yashkul
# Processing Record of | edinburg
# Processing Record of | muisne
# Processing Record of | mackay
# Processing Record of | touros
# Processing Record of | iqaluit
# Processing Record of | mayskiy
# Processing Record of | ostersund
# Processing Record of | marsh harbour
# Processing Record of | gizo
# Processing Record of | vardo
# Processing Record of | pozo colorado
# Processing Record of | bombay
# Processing Record of | pont-sainte-maxence
# Processing Record of | akureyri
# Processing Record of | murmashi
# Processing Record of | peresichna
# Processing Record of | dubbo
# Processing Record of | richards bay
# Processing Record of | gazion
# City not found.  Skipping...
# Processing Record of | mahibadhoo
# Processing Record of | nelson bay
# Processing Record of | rawson
# Processing Record of | nizhneyansk
# City not found.  Skipping...
# Processing Record of | belaya gora
# Processing Record of | taos
# Processing Record of | brae
# Processing Record of | aflu
# City not found.  Skipping...
# Processing Record of | kaohsiung
# Processing Record of | northam
# Processing Record of | cottbus
# Processing Record of | apc
# Processing Record of | zhaozhou
# Processing Record of | sarangarh
# Processing Record of | griffith
# Processing Record of | pathein
# Processing Record of | champerico
# Processing Record of | bahce
# Processing Record of | alihe
# Processing Record of | ekimchan
# Processing Record of | sao jose da coroa grande
# Processing Record of | peace river
# Processing Record of | dakoro
# Processing Record of | westport
# Processing Record of | vila velha
# Processing Record of | merauke
# Processing Record of | buraydah
# Processing Record of | uyuni
# Processing Record of | zapolyarnyy
# Processing Record of | iquitos
# Processing Record of | menongue
# Processing Record of | yar-sale
# Processing Record of | tarabuco
# Processing Record of | kiunga
# Processing Record of | cam ranh
# Processing Record of | manono
# Processing Record of | utiroa
# City not found.  Skipping...
# Processing Record of | carson city
# Processing Record of | parakou
# Processing Record of | turochak
# Processing Record of | kavaratti
# Processing Record of | golden rock
# City not found.  Skipping...
# Processing Record of | ashqelon
# Processing Record of | goya
# Processing Record of | juneau
# Processing Record of | shalya
# Processing Record of | flinders
# Processing Record of | stornoway
# City not found.  Skipping...
# Processing Record of | sobolevo
# Processing Record of | krasnoselkup
# City not found.  Skipping...
# Processing Record of | amapa
# Processing Record of | havoysund
# Processing Record of | thunder bay
# Processing Record of | belmonte
# Processing Record of | pangnirtung
# Processing Record of | tagusao
# Processing Record of | mattru
# Processing Record of | sofiysk
# City not found.  Skipping...
# Processing Record of | tura
# Processing Record of | leshukonskoye
# Processing Record of | whitianga
# Processing Record of | flin flon
# Processing Record of | kuhdasht
# Processing Record of | tsabong
# Processing Record of | upington
# Processing Record of | ambodifototra
# City not found.  Skipping...
# Processing Record of | gornji milanovac
# Processing Record of | armacao de pera
# Processing Record of | codrington
# Processing Record of | almaznyy
# Processing Record of | fortuna
# Processing Record of | filadelfia
# Processing Record of | harper
# Processing Record of | kazalinsk
# City not found.  Skipping...
# Processing Record of | moindou
# Processing Record of | husavik
# Processing Record of | terrak
# Processing Record of | gurskoye
# City not found.  Skipping...
# Processing Record of | kegayli
# City not found.  Skipping...
# Processing Record of | cascais
# Processing Record of | shadegan
# Processing Record of | liwale
# Processing Record of | shelburne
# Processing Record of | labrea
# City not found.  Skipping...
# Processing Record of | dianopolis
# City not found.  Skipping...
# Processing Record of | cockburn town
# Processing Record of | payakumbuh
# Processing Record of | moranbah
# Processing Record of | les cayes
# Processing Record of | luganville
# Processing Record of | bereda
# Processing Record of | port blair
# Processing Record of | toliary
# City not found.  Skipping...
# Processing Record of | panzhihua
# Processing Record of | kahului
# Processing Record of | saint-pierre
# Processing Record of | tutoia
# Processing Record of | calamar
# Processing Record of | heihe
# Processing Record of | san policarpo
# Processing Record of | deputatskiy
# Processing Record of | constitucion
# Processing Record of | ende
# Processing Record of | steamboat springs
# Processing Record of | chase
# Processing Record of | samarai
# Processing Record of | mugur-aksy
# Processing Record of | grindavik
# Processing Record of | sandpoint
# Processing Record of | kumher
# Processing Record of | gimli
# Processing Record of | kuusamo
# Processing Record of | sorvag
# City not found.  Skipping...
# Processing Record of | vung tau
# Processing Record of | temaraia
# City not found.  Skipping...
# Processing Record of | te anau
# Processing Record of | juan aldama
# Processing Record of | starkville
# Processing Record of | anito
# Processing Record of | porosozero
# Processing Record of | bolungarvik
# City not found.  Skipping...
# Processing Record of | svetlogorsk
# Processing Record of | kendari
# Processing Record of | sakhon nakhon
# City not found.  Skipping...
# Processing Record of | dongsheng
# Processing Record of | huadian
# Processing Record of | bose
# Processing Record of | dingle
# Processing Record of | henties bay
# Processing Record of | kharod
# Processing Record of | victor harbor
# Processing Record of | napasar
# Processing Record of | jinchang
# Processing Record of | porangatu
# Processing Record of | bousso
# City not found.  Skipping...
# Processing Record of | maldonado
# Processing Record of | tessalit
# Processing Record of | colesberg
# Processing Record of | samaro
# Processing Record of | zhangye
# Processing Record of | adamas
# Processing Record of | lake charles
# Processing Record of | port hedland
# Processing Record of | honningsvag
# Processing Record of | salinas
# Processing Record of | luan
# Processing Record of | rey bouba
# Processing Record of | lucera
# Processing Record of | yumen
# Processing Record of | waddan
# Processing Record of | posevnaya
# -------------------------------------
# Data Retrieval Complete
# -------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#len(cityNames)
#len(date)
#len(lat)
#len(lng)
#len(cloudiness)
#len(maxTemp)
#len(windSpeed)
#len(country)
#len(humidity)
# Out:
# 559

# %%
weather_dict = {
    "City": cityNames,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Long": lng,
    "Max Temp": maxTemp,
    "Wind Speed": windSpeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.to_csv("Resources/weather.csv", index = False, header = True)
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Long  \
# 0      Hermanus           0      ZA  1538258190        69 -34.42   19.24
# 1      Lorengau           0      PG  1538258188       100  -2.02  147.27
# 2  Norman Wells          20      CA  1538254800        60  65.28 -126.83
# 3        Lompoc           1      US  1538256900        53  34.64 -120.46
# 4        Atuona          56      PF  1538258206       100  -9.80 -139.03
#
#    Max Temp  Wind Speed
# 0   282.678        1.67
# 1   301.628        4.87
# 2   277.150        5.10
# 3   295.950        1.50
# 4   299.328        4.87

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_data_read = pd.read_csv("Resources/weather.csv")
weather_data_read.head()
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker = "o")

plt.title("City Latitude vs. Max Temperature (09/28/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()

plt.savefig("LatitudevsTemperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker = "o")

plt.title("City Latitude vs. Humidity (09/28/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

plt.savefig("LatitudevsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker = "o")

plt.title("City Latitude vs. Cloudiness (09/28/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

plt.savefig("LatitudevsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker = "o")

plt.title("City Latitude vs. Wind Speed (09/28/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()

plt.savefig("LatitudevsWind.png")
